# %% [markdown]
# <a href="https://colab.research.google.com/github/jiho01/Self-driving_AI/blob/main/0623_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
x = 10
y = "효상"

print(str(x)+y)
# Out:
# 10효상

# %%
print("Enter name!")
your_name = input("Your name : ")
print("your name is " + your_name)
# Out:
# Enter name!
# Your name : jiho
# your name is jiho

# %%
if int(input()) > 10 :
  print("This is bigger than 10")
else:
  print("This is smaller than 10")
# Out:
# 11
# This is bigger than 10

# %%
tuple_fruit = ("apple", "bnana", "tomato")

for x in tuple_fruit:
  print(x)
# Out:
# apple
# bnana
# tomato

# %%
dictionaries_car = {
    "brand": "Hyundai",
    "model": "Sonata",
    "year" : 2024
}

print(dictionaries_car['brand'])
# Out:
# Hyundai

# %%
list_animal = ["horse", "cat", "dog"]

for x in list_animal:
  print(x)
# Out:
# horse
# cat
# dog
